# %% [markdown]
# # Fine-Tuning – Austrian Tax Law
#
# **Model:** Qwen2-1.5B (Unsloth / LoRA Fine-Tuning)
#
# ---
#
# ## How does the model work?
#
# This notebook fine-tunes a small language model (Qwen2-1.5B) using LoRA (Low-Rank Adaptation)
# on a custom dataset of Austrian tax law Q&A pairs extracted from WU exam papers and other tax sources (listed below).
# After training, the fine-tuned model is used to answer all 643 questions from the test set.
#
# ---
#
# ## Setup
#
# 1. Upload FT_qa_new.csv (training data) and dataset_clean.csv (test set) to Google Drive
# 2. Adjust the file paths in Cell 4 if needed
# 3. Run all cells in order
# 4. Make sure the runtime is set to T4 GPU: Runtime > Change runtime type > T4 GPU
#
# ---
#
# ## Data
#
# **Training data:** 113 Q&A pairs manually extracted from WU exam papers on Austrian tax law, accountant Q&As and public inforamtion about tax law.
# (topics: EStG, KStG, UStG, BAO). Created as a CSV with columns question and answer.
#
# - https://res-wth.at/service/h%C3%A4ufige-fragen
# - https://www.salzburg.gv.at/ehrenamt/fragen-und-antworten-steuerrecht
# - https://www.studocu.com/de-at/document/universitat-wien/steuerrecht/falle-steuerrecht/57034172
# - https://ksw.or.at/berufszugang-berufsanwaerterinnen/fachpruefungen-wtbg-2017/downloads/#c2123
#
# **Test data:** The dataset_clean.csv contains 643 questions on Austrian tax law.
# Each question is identified by a unique id and a prompt in German.
# The dataset was used exclusively as a test set — it was never used for training.

# %% [markdown]
# ## Cell 1 - Install
# Installs Unsloth and the datasets library. Unsloth enables
# efficient 4-bit LoRA fine-tuning on T4 GPU.

# %%
# %%capture
# !pip install unsloth
# !pip install datasets

# %% [markdown]
# ## Cell 2 - Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Cell 3 - Find CSV files in Drive

# %%
import os
for root, dirs, files in os.walk("/content/drive/MyDrive"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/Colab Notebooks/dataset_clean.csv
# /content/drive/MyDrive/Colab Notebooks/output_rag_mistral.csv
# /content/drive/MyDrive/Colab Notebooks/FT_qa.csv
# /content/drive/MyDrive/Colab Notebooks/FT_qa_new.csv
# /content/drive/MyDrive/Colab Notebooks/submission_run3.csv

# %% [markdown]
# ## Cell 4 – Configuration
#
# Central configuration for all paths, model name, and hyperparameters.
# All settings are defined here to keep the notebook reproducible without hardcoded values.

# %%
TRAIN_CSV_PATH   = "/content/drive/MyDrive/Colab Notebooks/FT_qa_new.csv"
DATASET_CSV_PATH = "/content/drive/MyDrive/Colab Notebooks/dataset_clean.csv"
OUTPUT_CSV_PATH  = "/content/drive/MyDrive/Colab Notebooks/submission_run4.csv"
MODEL_OUTPUT_DIR = "/content/drive/MyDrive/Colab Notebooks/qwen_finetun"

MODEL_NAME = "unsloth/Qwen2-1.5B"

MAX_SEQ_LENGTH    = 1040.       # maximum number of tokens per training example
NUM_EPOCHS        = 5           # number of full passes through the training dataset
BATCH_SIZE        = 2           # samples processed per GPU step
GRAD_ACCUMULATION = 4           # simulates a larger batch by accumulating gradients over 4 steps
LEARNING_RATE     = 2e-4        # learning rate: controls how much the model weights change per update step


LORA_R       = 16               # scaling factor applied to the LoRA update
LORA_ALPHA   = 32               # acts as regularization to prevent overfitting on the small training set
LORA_DROPOUT = 0.05

print("Configuration loaded.")
# Out:
# Configuration loaded.

# %% [markdown]
# ## Cell 5 – Load base model
#
# Loads the Qwen2-1.5B base model with 4-bit quantization via Unsloth.
# 4-bit quantization reduces VRAM usage so the model fits on a T4 GPU (14.5 GB).

# %%
from unsloth import FastLanguageModel

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=MODEL_NAME,
    max_seq_length=MAX_SEQ_LENGTH,
    dtype=None,
    load_in_4bit=True,
)

print("Model loaded.")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.4.4: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# 'The read operation timed out' thrown while requesting HEAD https://huggingface.co/unsloth/Qwen2-1.5B-bnb-4bit/resolve/main/generation_config.json
# WARNING:huggingface_hub.utils._http:'The read operation timed out' thrown while requesting HEAD https://huggingface.co/unsloth/Qwen2-1.5B-bnb-4bit/resolve/main/generation_config.json
# Retrying in 1s [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Retrying in 1s [Retry 1/5].
# generation_config.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# 'The read operation timed out' thrown while requesting HEAD https://huggingface.co/unsloth/Qwen2-1.5B-bnb-4bit/resolve/main/merges.txt
# WARNING:huggingface_hub.utils._http:'The read operation timed out' thrown while requesting HEAD https://huggingface.co/unsloth/Qwen2-1.5B-bnb-4bit/resolve/main/merges.txt
# Retrying in 1s [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Retrying in 1s [Retry 1/5].
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/107 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# Model loaded.

# %% [markdown]
# ## Cell 6 – Add LoRA adapter
#
# Attaches a LoRA adapter to the frozen base model. Only ~0.28% of all parameters
# are trained, which drastically reduces memory usage and training time
# while still adapting the model to the target domain.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],    # attention layers to adapt
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=42,
)

model.print_trainable_parameters()
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2026.4.4 patched 28 layers with 0 QKV layers, 0 O layers and 0 MLP layers.
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815

# %% [markdown]
# ## Cell 7 – Load and prepare training data
#
# Loads the custom Q&A dataset from Google Drive, cleans it, and formats each
# example as an instruction-tuning prompt: system instruction + question + answer.
# This format teaches the model the desired response style.

# %%
import pandas as pd
from datasets import Dataset

df_train = pd.read_csv(TRAIN_CSV_PATH)
df_train.columns = df_train.columns.str.strip().str.lower()

if "question" not in df_train.columns or "answer" not in df_train.columns:
    raise ValueError(f"Columns found: {df_train.columns.tolist()}")

df_train["question"] = df_train["question"].str.strip()
df_train["answer"]   = df_train["answer"].str.strip()
df_train = df_train.dropna(subset=["question", "answer"])
df_train = df_train[df_train["question"].str.len() > 5]
df_train["question"] = df_train["question"].apply(lambda x: x.split("\n")[0].strip())

def format_prompt(row):
    return "\n".join([
        "Du bist ein Experte fuer oesterreichisches Steuerrecht.",
        "Beantworte die folgende Frage praezise und korrekt.",
        "Nenne wenn moeglich den relevanten Paragraphen (z.B. § 1 EStG, § 6 UStG).",
        "Antworte auf Deutsch in 2-4 saetzen.",
        "",
        "### Frage:",
        row["question"],
        "",
        "### Antwort:",
        row["answer"],
    ])

df_train["text"] = df_train.apply(format_prompt, axis=1)
train_dataset = Dataset.from_pandas(df_train[["text"]])

print(f"Training samples: {len(train_dataset)}")
print(train_dataset[0]["text"][:300])
# Out:
# Training samples: 113
# Du bist ein Experte fuer oesterreichisches Steuerrecht.
# Beantworte die folgende Frage praezise und korrekt.
# Nenne wenn moeglich den relevanten Paragraphen (z.B. § 1 EStG, § 6 UStG).
# Antworte auf Deutsch in 2-4 saetzen.
#
# ### Frage:
# Was ist der Unterschied zwischen Bilanz und Einnahmen/Ausgabenrechnun

# %% [markdown]
# ## Cell 8 – Train
#
# Runs the Supervised Fine-Tuning (SFT) via Unsloth's SFTTrainer.
# Training takes approximately 2 minutes for 5 epochs on 113 samples on a T4 GPU.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bf16_supported

training_args = TrainingArguments(
    output_dir=MODEL_OUTPUT_DIR,
    num_train_epochs=NUM_EPOCHS,
    per_device_train_batch_size=BATCH_SIZE,
    gradient_accumulation_steps=GRAD_ACCUMULATION,
    learning_rate=LEARNING_RATE,
    fp16=not is_bf16_supported(),
    bf16=is_bf16_supported(),
    logging_steps=5,
    save_strategy="epoch",
    optim="adamw_8bit",
    lr_scheduler_type="cosine",       # learning rate decreases following a cosine curve
    warmup_steps=5,
    report_to="none",
)

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    args=training_args,
    tokenizer=tokenizer,
    dataset_text_field="text",
    max_seq_length=MAX_SEQ_LENGTH,
    packing=False,
)

print("Starting training...")
trainer.train()
print("Training complete.")
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/113 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# Starting training...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 113 | Num Epochs = 5 | Total steps = 75
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 4,358,144 of 1,548,072,448 (0.28% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
#     <div>
#
#       <progress value='75' max='75' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [75/75 01:40, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.938558</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.638460</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.171234</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.761159</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.849848</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.693693</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.594050</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.673773</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.527851</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.409580</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.654936</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.419571</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.411105</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.514840</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.498115</td>
#     </tr>
#   </tbody>
# </table><p>
# Training complete.

# %% [markdown]
# ## Cell 9 - Save model

# %%
model.save_pretrained(MODEL_OUTPUT_DIR)
tokenizer.save_pretrained(MODEL_OUTPUT_DIR)
print(f"Model saved to {MODEL_OUTPUT_DIR}")
# Out:
# Model saved to /content/drive/MyDrive/Colab Notebooks/qwen_finetun

# %% [markdown]
# ## Cell 10 - Load model for inference

# %%
from unsloth import FastLanguageModel

inference_model, inference_tokenizer = FastLanguageModel.from_pretrained(
    model_name=MODEL_OUTPUT_DIR,
    max_seq_length=MAX_SEQ_LENGTH,
    dtype=None,
    load_in_4bit=True,
)

FastLanguageModel.for_inference(inference_model)
print("Model ready for inference.")
# Out:
# ==((====))==  Unsloth 2026.4.4: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# Model ready for inference.

# %% [markdown]
# ## Cell 11 – Inference function
#
# Defines the answer generation function. Uses temperature=0.3 for focused outputs
# and repetition_penalty=1.4 to avoid repeated sentences.

# %%
def generate_answer(question: str, max_new_tokens: int = 150) -> str:
    prompt = "\n".join([
        "Du bist ein Experte für österreichisches Steuerrecht.",
        "Beantworte die folgende Frage klar und kurz ohne Beispiel.",
        "Antworte mit 2 Sätzen.",
        "",
        "### Frage:",
        question,
        "",
        "### Antwort:",
        "",
    ])
    inputs = inference_tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=MAX_SEQ_LENGTH,
    ).to(inference_model.device)

    with torch.no_grad():
        outputs = inference_model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,            # maximum number of tokens to generate
            do_sample=True,                           # enable sampling (required for temperature)
            temperature=0.3,                          # low temperature: focused, less random output
            top_p=0.9,                                # consider top 90% probability mass
            repetition_penalty=1.4,                   # penalizes repeated tokens to avoid loops
            pad_token_id=inference_tokenizer.eos_token_id,
        )

    generated = outputs[0][inputs["input_ids"].shape[1]:]
    answer = inference_tokenizer.decode(generated, skip_special_tokens=True).strip()

    sentences = answer.split(". ")
    seen = []
    for s in sentences:
        if s.strip() not in seen:
            seen.append(s.strip())
    return ". ".join(seen)

# %% [markdown]
# ## Cell 12 – Run inference on all 643 questions
#
# Generates answers for all 643 questions from dataset_clean.csv.
# A checkpoint is saved every 50 answers to Google Drive — if the connection drops,
# the process resumes automatically from the last checkpoint.

# %%
import torch
import pandas as pd

df_preview = pd.read_csv(DATASET_CSV_PATH)

question_col = None
for col in df_preview.columns:
    if col.lower() in ["question", "frage", "text", "input"]:
        question_col = col
        break
if question_col is None:
    question_col = df_preview.columns[1]

for i in range(5):
    question = str(df_preview[question_col].iloc[i])
    answer = generate_answer(question)
    print(f"--- ID: {df_preview['id'].iloc[i]} ---")
    print(f"Frage: {question}")
    print(f"Antwort: {answer}")
    print()
# Out:
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- ID: CORP-TAX-001 ---
# Frage: Was ist die steuerliche Bemessungsgrundlage für die Körperschaftsteuer?
# Antwort: Die BEMESSUNGSLAGE der KÖRPERSTEUREN liegt auf dem EINTEILIGEN INVESTMENTERGANGSVERLÄUGEN
# der Gesellschaft. Die Investitionen sind in zwei Gruppen unterteilt: (1) das gesamtenvertriebene Kapital, welches durch den Verkauf von Aktien oder anderen Erwerbsmitteln an andere Personen ausgegeben wird; sowie (2)
# das nichtgesamtverdiente Kapitalet aus allen weiteren Mittel des Unternehmens,
# die als Gewinn erzielt werden können. Das kapitaleinländische Kapitel bezieht sich hierbei nur auf das
# Kap
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- ID: CORP-TAX-002 ---
# Frage: Welche steuerlichen Konsequenzen hat es, wenn eine Körperschaft ein zinsloses Darlehen an ihren Gesellschafter vergibt?
# Antwort: Die GESCHWALD-Veranlagung ist auf den gesamten Betriebsbetrieb zu übertragen. Die
# Gesellschaft kann sich damit nicht aus dem Verhältnisminderungsverlust profitieren,
# da der Eintrag in das Einkommenssteuergeld nach §13 Absatz 4 BStU (EINKOMMENSSTEUGELDE)
# nicht erlaubt wird. Der Ausgleichsanteil des betreffenden Geschäftsbetreibers liegt bei einem
# zweifelsfreien Vorstellungenstausch zwischen beiden Parteien unter anderem durch einen
# Kostenentzug oder einer Gewinnabnahme im
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- ID: CORP-TAX-003 ---
# Frage: Welche Körperschaften sind verpflichtet, sämtliche Einkünfte den Einkünften aus Gewerbebetrieb zuzurechnen?
# Antwort: Korporationsgesellschaft (§15 Abs.3 UStG) ist nicht nur von der Verwendung des
# Ersatzsteuerschutzes betroffen sondern auch vom Betriebsvermögen abzustreichen,
# da es sich um eine gesetzlich erlaubte Finanzierungsmöglichkeit handelt.(Zum Ausgleichs-
# Berechtigungsgesuch: §68a StGB). Der Begriff „Betreibergewinn“ bezieht sich auf das Gesamtbeträge-
# gewinne einer Unternehmenskette bzw. eines Geschäftsbürgersystems in einem bestimmten Zeitraums („Tagesg
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- ID: CORP-TAX-004 ---
# Frage: Wie wird eine Dividende einer österreichischen Tochtergesellschaft (a) bei der Tochter und (b) bei der österreichischen Muttergesellschaft steuerlich behandelt?
# Antwort: Die toten Gesellschafter haben in Österreich keine Mehrwertsteuern zu bezahlen. Die
# Tochteschaften sind nicht mehr als Vorhabensvermögen, sondern werden von den
# Mehrkassen abgeleitet: Das ist auch so im Fall eines Verbrauchershauses aufgrund des
# Gesetzlichen Vorsatzs zur Erwerbsfinanzierung möglich. Der Wert dieser gesellshäuptliche
# Vorhandenseitigkeit kann durch einen Anstieg oder Abfall an Gewinnanteile aus dem
# Einkommenssaldo bestimmt werden; es muss aber immer mindestens das Ersparnisvolumen sein,
# das sich vom Bet
#
# --- ID: CORP-TAX-005 ---
# Frage: Was unterscheidet die steuerliche Behandlung einer offenen von einer verdeckten Ausschüttung auf Ebene der ausschüttenden Körperschaft?
# Antwort: Die Versteckte Ausgabe ist eine ausdrücklich oder unvermeidlichen
# Ausgaben, bei denen das Einkommen nicht direkt durch den Betrieb erzielt wird. Bei einem öffentligen Unternehmen kann diese Art des Unternehmensunterhaltens auch als Offenheitseinsatz bezeichnet werden (z.B.: "Der Geschäftsführer hat sich in seinem eigenen Haus eingesetzt").
# Bei privaten Personen sind solche Expendituren aber normalerweise illegal,
# weil sie unter dem Gesetz zur Finanzierungspflicht zu fallen haben müssen.[1]
# Es gibt also zwei unterschiedliche Formen: Eine Öffentliches Unternehmen darf nur so viel
# ausgeben wie

# %%
import pandas as pd
from tqdm import tqdm
import os

df_test = pd.read_csv(DATASET_CSV_PATH)

question_col = None
for col in df_test.columns:
    if col.lower() in ["question", "frage", "text", "input"]:
        question_col = col
        break
if question_col is None:
    question_col = df_test.columns[1]

print(f"Using column: '{question_col}'")

CHECKPOINT_PATH = "/content/drive/MyDrive/Colab Notebooks/checkpoint_answers.csv"

# falls bereits ein checkpoint existiert, weitermachen wo aufgehört
if os.path.exists(CHECKPOINT_PATH):
    df_checkpoint = pd.read_csv(CHECKPOINT_PATH)
    answers = df_checkpoint["answer"].tolist()
    start_idx = len(answers)
    print(f"Resuming from index {start_idx}.")
else:
    answers = []
    start_idx = 0
    print("Starting fresh.")

for i, row in tqdm(df_test.iloc[start_idx:].iterrows(), total=len(df_test)-start_idx, desc="Generating answers"):
    answer = generate_answer(str(row[question_col]))
    answers.append(answer)

    # alle 50 antworten speichern
    if len(answers) % 50 == 0:
        df_temp = pd.DataFrame({
            "id": df_test["id"].iloc[:len(answers)].values,
            "answer": answers,
        })
        df_temp.to_csv(CHECKPOINT_PATH, index=False)
        print(f"Checkpoint saved at {len(answers)} answers.")

print(f"Done. {len(answers)} answers generated.")
# Out:
# Using column: 'prompt'
# Starting fresh.
# Generating answers:   0%|          | 0/643 [00:00<?, ?it/s]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Generating answers:   0%|          | 1/643 [00:07<1:16:53,  7.19s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   0%|          | 2/643 [00:15<1:22:50,  7.75s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   0%|          | 3/643 [00:17<57:39,  5.41s/it]  Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          | 4/643 [00:26<1:09:13,  6.50s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          | 5/643 [00:33<1:11:41,  6.74s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          |
/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:  99%|█████████▉| 639/643 [1:07:14<00:24,  6.23s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers: 100%|█████████▉| 640/643 [1:07:22<00:20,  6.76s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers: 100%|█████████▉| 641/643 [1:07:29<00:13,  6.87s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers: 100%|█████████▉| 642/643 [1:07:33<00:06,  6.12s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers: 100%|██████████| 643/643 [1:07:41<00:00,  6.32s/it]
# Done. 643 answers generated.

# %%
#from tqdm import tqdm

#df_test = pd.read_csv(DATASET_CSV_PATH)
#print(f"Loaded {len(df_test)} questions.")
#print(f"Columns: {df_test.columns.tolist()}")

#question_col = None
#for col in df_test.columns:
 #   if col.lower() in ["question", "frage", "text", "input"]:
  #      question_col = col
   #     break
#if question_col is None:
 #   question_col = df_test.columns[1]

#print(f"Using column: '{question_col}'")

#answers = []
#for i, row in tqdm(df_test.iterrows(), total=len(df_test), desc="Generating answers"):
 #   answer = generate_answer(str(row[question_col]))
  #  answers.append(answer)

#print(f"Done. {len(answers)} answers generated.")
# Out:
# Loaded 643 questions.
# Columns: ['id', 'prompt']
# Using column: 'prompt'
# Generating answers:   0%|          | 0/643 [00:00<?, ?it/s]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Generating answers:   0%|          | 1/643 [00:08<1:28:08,  8.24s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   0%|          | 2/643 [00:15<1:22:45,  7.75s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   0%|          | 3/643 [00:23<1:23:11,  7.80s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          | 4/643 [00:31<1:23:44,  7.86s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          | 5/643 [00:38<1:21:21,  7.65s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          | 6/643 [00:46<1:23:03,  7.82s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          | 7/643 [00:53<1:20:19,  7.58s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|          | 8/643 [01:02<1:22:08,  7.76s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   1%|▏         | 9/643 [01:06<1:11:09,  6.73s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   2%|▏         | 10/643 [01:14<1:15:40,  7.17s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   2%|▏         | 11/643 [01:16<56:30,  5.36s/it]  Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   2%|▏         | 12/643 [01:23<1:02:35,  5.95s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   2%|▏         | 13/643 [01:31<1:09:17,  6.60s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   2%|▏         | 14/643 [01:34<58:06,  5.54s/it]  Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   2%|▏         | 15/643 [01:42<1:06:16,  6.33s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   2%|▏         | 16/643 [01:45<56:15,  5.38s/it]  Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   3%|▎         | 17/643 [01:53<1:02:42,  6.01s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   3%|▎         | 18/643 [01:58<1:00:12,  5.78s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   3%|▎         | 19/643 [02:06<1:06:15,  6.37s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   3%|▎         | 20/643 [02:13<1:09:40,  6.71s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   3%|▎         | 21/643 [02:21<1:13:56,  7.13s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   3%|▎         | 22/643 [02:29<1:13:54,  7.14s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   4%|▎         | 23/643 [02:43<1:35:09,  9.21s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   4%|▎         | 24/643 [02:59<1:56:52, 11.33s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   4%|▍         | 25/643 [03:10<1:55:39, 11.23s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating answers:   4%|▍         | 25/643 [03:16<1:20:59,  7.86s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7216/2951098138.py in <cell line: 0>()
#      17 answers = []
#      18 for i, row in tqdm(df_test.iterrows(), total=len(df_test), desc="Generating answers"):
# ---> 19     answer = generate_answer(str(row[question_col]))
#      20     answers.append(answer)
#      21
#
# /tmp/ipykernel_7216/2632792268.py in generate_answer(question, max_new_tokens)
#      19
#      20     with torch.no_grad():
# ---> 21         outputs = inference_model.generate(
#      22             **inputs,
#      23             max_new_tokens=max_new_tokens,
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in generate(self, *args, **kwargs)
#    2046                 with self._enable_peft_forward_hooks(*args, **kwargs):
#    2047                     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 2048                     outputs = self.base_model.generate(*args, **kwargs)
#    2049             else:
#    2050                 outputs = self.base_model.generate(**kwargs)
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in unsloth_fast_generate(self, *args, **kwargs)
#    2130         torch.autocast(device_type = DEVICE_TYPE_TORCH, dtype = dtype),
#    2131     ):
# -> 2132         output = self._old_generate(*args, **kwargs)
#    2133
#    2134     # Return accelerate back
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2541
#    2542         # 9. Call generation mode
# -> 2543         result = decoding_method(
#    2544             self,
#    2545             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2748                 )
#    2749                 with self._optimize_model_for_decode():
# -> 2750                     outputs = model_forward(**model_inputs, return_dict=True)
#    2751             prefill_consumed = True
#    2752             model_kwargs = self._update_model_kwargs_for_generation(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in _CausalLM_fast_forward(self, input_ids, causal_mask, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, num_logits_to_keep, logits_to_keep, *args, **kwargs)
#    1448     ) -> Union[Tuple, CausalLMOutputWithPast]:
#    1449         if past_key_values is not None:
# -> 1450             outputs = fast_forward_inference(
#    1451                 self,
#    1452                 input_ids,
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in LlamaModel_fast_forward_inference_custom(self, input_ids, past_key_values, position_ids, attention_mask, **kwargs)
#    1397                 variance = variance,
#    1398             )
# -> 1399             X = mlp_fast_forward_inference(
#    1400                 decoder_layer.mlp,
#    1401                 X,
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in fast_swiglu_inference(self, X, temp_gate, temp_up, gate_multiplier, down_multiplier)
#     634
#     635     # X = self.down_proj(gate)
# --> 636     down = fast_linear_forward(self.down_proj, gate, out = up[:, :, :hd])
#     637
#     638     if down_multiplier is not None:
#
# /usr/local/lib/python3.12/dist-packages/unsloth/kernels/utils.py in fast_linear_forward(proj, X, temp_lora, out)
#     977         out = fp8_linear(X, W, W_quant, bias)
#     978     elif bsz == 1 and q_len == 1:
# --> 979         out = fast_gemv(X, W, W_quant, out = out)
#     980     else:
#     981         W = fast_dequantize(W.t(), W_quant, use_global_buffer = True)
#
# /usr/local/lib/python3.12/dist-packages/unsloth/kernels/utils.py in fast_gemv(X, W, quant_state, out)
#     826         ldc = ctypes_c_int32(ldc)
#     827
# --> 828         df = torch_empty(absmax.shape, dtype = torch_float32, device = device)
#     829         with torch_gpu_device(device):
#     830             cdequantize_blockwise_fp32(
#
# KeyboardInterrupt:

# %% [markdown]
# ## Cell 13 - Save submission CSV

# %%
df_submission = pd.DataFrame({
    "id": df_test["id"],
    "answer": answers,
})

df_submission.to_csv(OUTPUT_CSV_PATH, index=False)
print(f"Saved to: {OUTPUT_CSV_PATH}")
print(df_submission.head(20).to_string())
# Out:
# Saved to: /content/drive/MyDrive/Colab Notebooks/submission_run4.csv
#               id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              answer
# 0   CORP-TAX-001                                             Die steuersichere Einnahmen sind der Grundlagenwert. Die Erwerbsnachweisung\nist das Hauptmittel zur Berechnung des Grundläufens, wobei aber auch andere\nBegriffe wie Gewerbeanstehungen oder Verbrauchswert (Wirtschaftsverkehr) in den\nKostenvorstellungen eingesetzt werden können. Der Grundlageneinsatz wird durch\ndie Ausgaben- bzw. Kostenentwicklung bestimmt: Das Ergebnis von einer Investition,\nzumal sie sich nicht auf eine bestimmte Zeit beschränkt, kann nur aus dem Gesamt-\nErsparnis entstanden sein; wenn es jedoch zu einem er
# 1   CORP-TAX-002                                       Die Versteigerung des darleselnen Betrages ist als Gewinn aus dem Geschäft zu\nunterzeichnen. Der Vorzug der Einkommensabnahme wird nicht mehr genutzt (§13 Absatz 5 UStG).\nDer Unternehmer kann sich aber nochmals dennoch auf seine eigenen Rechnungen um so viel\nErsparnis wie möglich machen: Er darf in seiner selbst organisierten Finanzierungskette\ndie gesamte Abnahmenrate übernehmen; er muss nur sein Teil abgeben – das heißt,\ner bleibt bei seinem Einzelfinansierungsvermögen gleichbleibend. Das gilt auch dann, wenn\nder unternehmensge
# 2   CORP-TAX-003                                                                                                                                                                                                                                                                                                                                                                                                                                Korporationsgesellschaft\nUntergesetzete Gesellschaftergemeinsamkeit\n\n#### Beispiele:\n\n• Betriebsunternehmen (Bürokorp)\n• Unternehmensgruppe\n• Vertriebsschule
# 3   CORP-TAX-004                         Die toten Gesellschafter haben sich in den Verlusten des Unternehmens gemäß §10 Abs.3 EStG\nverblieben, so dass sie keine Mehrwertsteuern verpflichtet sind. Die toden Betriebsleute können aber als\nMinderbetriebler nach §§57 ff UmgE betrieben werden bzw. das Unternehmen übernehmen. Der Unterschied zu einem\nnormaler Geschäftsführungsunternehmer liegt darin, dass er nicht mehr seine persönlichen Mittel zur Verfügung stellt,\nsondert es an dem Unternehmen weiterzustellen ist. Für diese Leistung soll dann auch noch eine Vorstehung bestehen: Das\nUnters
# 4   CORP-TAX-005                                             Offen: Ausstößt in den Verkehr. Schadensersatzsteuern, Gewinnabzug\nVerdeckt (z.B. durch einen Unternehmensvertrag): Nicht ausgestoßen sondern nur als Einkommen zu betrachten\n\nEs gibt aber auch eine Art Offentlichkeit/Unoffentlichkeit bei dem Betrieb des ÖPNV-Unterhaltungsunternehmen,\ndass es nicht öffentlich ist oder sich jedoch im Allgemeinen unter anderem an das Publikum richtete:\n\nÖFPN-Vereinbarungen sind oft unpubliziert bzw. unbekannt; sie können also nicht publierter werden;\nsie haben keine rechtlichen Grundlagen wie
# 5   CORP-TAX-006                                                                              Die maximale Abzugsrate beträgt ca. 10% des Einkommens, wobei eine\nAbgrenzung zwischen den einzelnen Gewinnen möglich sein kann (Klasse I,\nII oder III). Die abgelegte Kostengruppe wird aufgrund von verschiedenen\nFaktoren wie z.B.: Anstiegskosten bei einer Kaufveranstaltung; Kosten aus dem\nWirtschaftsleben sowie Warenkunden- bzw. Kundenfremdwert ermittelt: Bei\nErsatzteilbeständen werden auch noch zusätzlichen Betriebsausgaben berücksichtigt;\ndie Erträge sind dann nach dieser Gesamtkoste zu re
# 6   CORP-TAX-007  Mantenkeufe sind nicht zu bestrafen. Es gibt aber eine Ausnahme, wenn\nder Kauf von einem anderen Unternehmen erfolgt (z.B. der Muttergesellschaft)\nund das Produkt dann in den eigenen Vertrieb überführt wird: Dann kann es sich um einen\nWirtschaftsverstoß handeln; da man hierbei keine Unternehmensausgleichung mehr macht,\nkann auch nur noch unter bestimmten Umständen gefordert werden, dass diese ausgestellt\nwerden müssen - zB nach dem Aufbau einer neuen Betriebsführung oder als Nachweis eines\nunternehmerischen Erfolgs bei Einkommensteuern bzw. beim Abzug des Gewinnabba
# 7   CORP-TAX-008                                                                                                                                                                                                                                                                                                                                                                                             Der Verlust ist nicht zu entziehen, sondern muss auf den Betriebsgutachten\naufgenommen werden. Die Kosten sind aber aus dem Gewinn abzugleichen,\nda sie als Vorsteuereinkünfte gelten (§14 Abschluß).
# 8   CORP-TAX-009                                                                                                                                                                                                                                                                                                                     Die Ausländer müssen den Gewinn (Verbrauch) nach dem Zeitpunkt des Jahresabschlusses\nabzüglich einer Abzugskennzahl abgeben. Die Inlandsgruppe muss aber nur auf das Jahr zurückgreifen,\ndass sie nicht mehr versteckt ist, sondern es gibt eine neue Kostengruppe zu prägen.
# 9   CORP-TAX-010                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Ja, wenn der Einzelne eine Veranlagung von Einkünften hat. Die\nGruppe kann aber nicht verantwortlich werden (z.B.: Kompensation).
# 10  CORP-TAX-011                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Ja, wenn der Betriebsvermögenseinsatz von dem gruppengewöhnlichen beträgt.
# 11  CORP-TAX-012                                                                                Die Versteigerung der Ausländerdividen ist nicht möglich. Die Anstiegswirkungen auf den deutschen\nBörsenmarkt sind aber zu vermeiden durch das Absetzungsverfahren (§38 Absatz 4 EStG). Für diese\nAnlage kann auch nochmals abgelegt werden: §76 Absatz 9 StGB + §30 UEGsVerhältnismäßig können sich\ndie angeschlossenen Aktien in einem Kurs von mehr als zwei Monaten nach dem Zeitpunkt des Einzelnennens\nabziehen. Bei diesem Fall muss dann nur noch gefordert worden sein um so viel wie möglicherweise er
# 12  CORP-TAX-013                                 Die Abzugsgesetze sind nicht unabhängig voneinander, sondern in der Regel nur untereinander\napplicable: Die Verwendung einer Begriffsklärungsgrundlage ist bei den beiden Gesetzgebungsausdrücken\nnicht möglich; sie müssen zusammengefasst werden oder durch eine gemeinsame Ausprägungen angegeben,\ndass beide Anforderungen erfüllt wurden. Bei dem Erwerb von Aktien eines Unternehmens kann das\nVerbraucherschutzgesetz als Gegenmaß zur Einführung des Kapitalsteuersatzes gesehen werden – sofern es sich um einen\nKonzernertrag handelt. Das Gewinnent
# 13  CORP-TAX-014                                                                   Die Vertragsparteien sind mindestens zwei. Die Begründung der internationalen\nSchachtelteilnahme muss in den Vereinbarungsvertrag enthalten werden, wobei sie\nnicht nur auf das Erschwerthum des Betriebs oder dem Gewinn ausdrücklich beziehen,\nsondern auch anhand einer konkreten Anwendungsberechnung angegeben ist (§10 Abs.3 UStG).\nDabei kann es sich um einen ganzzahligen Kostenvorgabe handeln; wenn nicht möglich wird,\ndie Kosten als zulässige Ausgaben zu betrachten bzw. von einem anderen Geschäftsfeld abzu
# 14  CORP-TAX-015                                                      Die Gewinnanteile der Börsengruppe sind als Gegensteuereinkommen\neingestellt. Die Umsatzgewinnausgaben, insbesondere das Geschäftsmaterial,\ndie Unternehmenskosten sowie den Betriebsschaden können nicht entgelenzt oder\nabgegeben worden sein (Kostenvorbehalte). Es ist aber möglich eine Ausgabe von\nGeschenken zu unterstellen: Bei einer Kompensation kann es sich um einen Geburtstagskastenschein handeln; bei einem Geschenktisch wird man aufgrund des Anstiegsverhältnisses an dem Preis erwartet. In diesem Fall muss diese Er
# 15  CORP-TAX-016                                                                                                                                                                                                                                                                                                                                                                                                                       Ja, wenn der Finanziertseiferstehende nicht selbst das Kapital zur Verfügung gestellt hat. Der\nFinanzierten muss aber nochmals zugesprochen werden (10% des Gesamtkapitals).
# 16  CORP-TAX-017                                                                                    § 11KSG: Ausgabeten, ausgewertete Einnahmen\n§ 12Ksg.: Umsatzsteuern\n\n#### Erklärung:\n\nDie Verwendung von Gewinnen oder Vermögen wird durch das Gesetz nicht verboten. Die Vorschriften des Bundesverfassungsgerichts (BVG) sind jedoch auch an solchen Personen Anwendbar,\ndie sich als Geschäftsführer einer GmbH befindet.[4] Das BGB bezieht sich also nur darauf ab wann eine Person zu einem Geschäftsführen zuständig sein soll bzw. welche Rechte sie damit besitzt. Es gibt keine allgemeine Regel
# 17  CORP-TAX-018                                                                                                                                                                                                                                                                                                                                                   Ja, wenn sie in der Regel nicht als Gewinnsatz ausgewiesen werden. Die\nGewinne sind aber auch dann ermittelt worden (nach §10 Abschlag). Bei den\nFreiwilligemitteln ist das Abzugsmaß angesagt auf dem Einkommenssteuersatze von\n6 % bis 45 %.
# 18  CORP-TAX-019                                                                      (a), b\nDie EGB ist eine Art von Gewinnsteuergesetz. Sie wird in der Regel durch das Bundesministerium des Innernaustauschgesetzes ausgestellt,\ndas sich aber auch auf den Bereich der Finanzierungsförderungsmaßnahmen bezieht. Die Erwerbs- bzw. Investitionsfinanziertreiberechte werden somit als\nEinsatzrechtsabzug betrachtet; sie entstehen jedoch im Rahmen eines Abtretens zu einem anderen Zweck nach dem § 14 Abs. 3 UStG unter anderem vom Landländerschaften zur Förderung bestimmter Maßnahmensgruppen wie zum
# 19  CORP-TAX-020                                                                                                                                           Lizenzgeburten können nur nach dem Erlass vom 1.06.98 (§3 Absatz 5) von der\nGesellcchaftssteuergeschäftsbeteiligung ausgeschlossen werden, wenn diese in den Jahren vorher zu einer\nSteuerschuldenentwicklung geführte Verluste aufgewiesen wurden oder bei einem Umstieg zur Staatseigeneheit\nnicht mehr als das durchgängigen Gewinnanteile angegeben waren bzw. es sich um einen Umsetzungsverstoß handelt,\nder im Rahmen des §47 GG verboten ist.

# %% [markdown]
# ## Cell 14 - Sanity check

# %%
df_check = pd.read_csv(OUTPUT_CSV_PATH)

assert len(df_check) == 643, f"Expected 643 rows, got {len(df_check)}"
assert "id" in df_check.columns, "Missing 'id' column"
assert "answer" in df_check.columns, "Missing 'answer' column"
assert df_check["answer"].isna().sum() == 0, "Empty answers found"

print("Sanity check passed.")
print(f"Total rows: {len(df_check)}")
print(f"Empty answers: {df_check['answer'].isna().sum()}")
print(f"Avg answer length: {df_check['answer'].str.len().mean():.0f} chars")
# Out:
# Sanity check passed.
# Total rows: 643
# Empty answers: 0
# Avg answer length: 425 chars
